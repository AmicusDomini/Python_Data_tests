# %%
import pandas as pd
import matplotlib.pyplot as plt

ay = pd.read_csv('hf://datasets/lukebarousse/data_jobs/data_jobs.csv')

ay['job_posted_date'] = pd.to_datetime (ay['job_posted_date'])

# %%
ay_salary=ay[pd.notna(ay['salary_year_avg'])]['salary_year_avg']

ay_salary
# Out:
# 28        109500.0
# 77        140000.0
# 92        120000.0
# 100       228222.0
# 109        89000.0
#             ...
# 785624    139216.0
# 785641    150000.0
# 785648    221875.0
# 785682    157500.0
# 785692    157500.0
# Name: salary_year_avg, Length: 22003, dtype: float64

# %%
help(ay.apply)
# Out:
# Help on method apply in module pandas.core.frame:
#
# apply(func: 'AggFuncType', axis: 'Axis' = 0, raw: 'bool' = False, result_type: "Literal['expand', 'reduce', 'broadcast'] | None" = None, args=(), by_row: "Literal[False, 'compat']" = 'compat', engine: "Literal['python', 'numba']" = 'python', engine_kwargs: 'dict[str, bool] | None' = None, **kwargs) method of pandas.core.frame.DataFrame instance
#     Apply a function along an axis of the DataFrame.
#
#     Objects passed to the function are Series objects whose index is
#     either the DataFrame's index (``axis=0``) or the DataFrame's columns
#     (``axis=1``). By default (``result_type=None``), the final return type
#     is inferred from the return type of the applied function. Otherwise,
#     it depends on the `result_type` argument.
#
#     Parameters
#     ----------
#     func : function
#         Function to apply to each column or row.
#     axis : {0 or 'index', 1 or 'columns'}, default 0
# ...

# %%
ay_salary=ay[pd.notna(ay['salary_year_avg'])].copy()

def projected_salary(salary):
    return salary * 1.03
ay_salary['salary_year_inflated']= ay_salary['salary_year_avg'].apply(projected_salary)

# %%
ay_salary[['salary_year_avg','salary_year_inflated']]
# Out:
#         salary_year_avg  salary_year_inflated
# 28             109500.0             112785.00
# 77             140000.0             144200.00
# 92             120000.0             123600.00
# 100            228222.0             235068.66
# 109             89000.0              91670.00
# ...                 ...                   ...
# 785624         139216.0             143392.48
# 785641         150000.0             154500.00
# 785648         221875.0             228531.25
# 785682         157500.0             162225.00
# 785692         157500.0             162225.00
#
# [22003 rows x 2 columns]

# %%
ay_salary['salary_year_inflated']= ay_salary['salary_year_avg'].apply(lambda salary:salary*1.03)

ay_salary[['salary_year_avg', 'salary_year_inflated']]
# Out:
#         salary_year_avg  salary_year_inflated
# 28             109500.0             112785.00
# 77             140000.0             144200.00
# 92             120000.0             123600.00
# 100            228222.0             235068.66
# 109             89000.0              91670.00
# ...                 ...                   ...
# 785624         139216.0             143392.48
# 785641         150000.0             154500.00
# 785648         221875.0             228531.25
# 785682         157500.0             162225.00
# 785692         157500.0             162225.00
#
# [22003 rows x 2 columns]

# %%
ay_salary['salary_year_hypinflate']= ay_salary['salary_year_avg']*1.10

# %%
ay_salary.head()
# Out:
#     job_title_short                                job_title  \
# 28   Data Scientist                      CRM Data Specialist
# 77    Data Engineer                            Data Engineer
# 92    Data Engineer  Remote - Data Engineer - Permanent - W2
# 100  Data Scientist  Data Scientist, Risk Data Mining - USDS
# 109    Data Analyst    Senior Supply Chain Analytics Analyst
#
#                                 job_location          job_via  \
# 28   San José Province, San José, Costa Rica  via Ai-Jobs.net
# 77                             Arlington, VA     via LinkedIn
# 92                                  Anywhere     via LinkedIn
# 100                        Mountain View, CA     via LinkedIn
# 109                                 Anywhere       via Get.It
#
#     job_schedule_type  job_work_from_home            search_location  \
# 28          Full-time               False                 Costa Rica
# 77          Full-time               False                      Sudan
# ...

# %%
ay['job_skills'][1]
# Out:
# "['r', 'python', 'sql', 'nosql', 'power bi', 'tableau']"

# %%
import ast

type (ast.literal_eval(ay['job_skills'][2]))
# Out:
# list

# %%
#def clean_list(skill_list):
 #   if pd.notna(skill_list):
  #      return ast.literal_eval(skill_list)

#ay['job_skills']= ay['job_skills'].apply(clean_list)

# %%
ay['job_skills'][10]
# Out:
# "['python', 'databricks', 'azure', 'spark']"

# %%
#OR
ay['job_skills']= ay['job_skills'].apply(lambda skill_list: 
                                         ast.literal_eval(skill_list) 
                                         if pd.notna (skill_list) else skill_list)

# %%
type(ay['job_skills'][3])
# Out:
# list

# %%
ay_salary
# Out:
#        job_title_short                                          job_title  \
# 28      Data Scientist                                CRM Data Specialist
# 77       Data Engineer                                      Data Engineer
# 92       Data Engineer            Remote - Data Engineer - Permanent - W2
# 100     Data Scientist            Data Scientist, Risk Data Mining - USDS
# 109       Data Analyst              Senior Supply Chain Analytics Analyst
# ...                ...                                                ...
# 785624   Data Engineer                   Data Analytics Engineer (Hybrid)
# 785641   Data Engineer                                      Data Engineer
# 785648  Data Scientist  Director Data Scientist - Commercial Platforms...
# 785682  Data Scientist  Data Scientist für datengetriebene Entwicklung...
# 785692  Data Scientist               Data Scientist- Hybrid Work Location
#
#                                    job_location          job_via  \
# ...

# %%
def projected_salary (row):
    if "Senior" in row ['job_title_short']:
        return 1.05 * row['salary_year_avg']
    else:
        return 1.03 * row['salary_year_avg']

ay_salary['salary_year_inflated']= ay_salary.apply (projected_salary, axis= 1)

ay_salary[['job_title_short','salary_year_avg','salary_year_inflated']].head(20)
# Out:
#           job_title_short  salary_year_avg  salary_year_inflated
# 28         Data Scientist         109500.0             112785.00
# 77          Data Engineer         140000.0             144200.00
# 92          Data Engineer         120000.0             123600.00
# 100        Data Scientist         228222.0             235068.66
# 109          Data Analyst          89000.0              91670.00
# 116        Data Scientist         114000.0             117420.00
# 146         Data Engineer         129500.0             133385.00
# 180          Data Analyst          90250.0              92957.50
# 212        Data Scientist         157500.0             162225.00
# 257        Data Scientist         103128.0             106221.84
# 307         Data Engineer         185000.0             190550.00
# 339         Data Engineer         195000.0             200850.00
# 380         Data Engineer          97500.0             100425.00
# ...
